# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)   #give id to every word so that we can find the word by the id 
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'as', 'of', 'originated', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  #shape 5000,128
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))   # 50000 word, each word is represented by a vector 128
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  #shape 5000,
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings)) #越大的元素越相近。

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.322750
# Nearest to four: writeup, switched, minivan, grammatical, violent, mores, crucifix, duodenum,
# Nearest to who: galilean, resistivity, tarragona, returning, lewiston, diocese, ecoregion, centaurs,
# Nearest to into: spokes, pohjola, librarian, daniell, leftist, shimon, wegener, frobisher,
# Nearest to three: templars, pleadings, chronicon, habitats, mistook, budget, consumption, aesthetics,
# Nearest to and: busta, fermentation, wei, binge, extension, conf, coughing, faithfulness,
# Nearest to however: rotations, lynda, kohlrabi, pumice, criswell, envoys, mair, islamic,
# Nearest to been: followed, unicef, hypertrophy, recalled, piecewise, kul, matilda, ordinances,
# Nearest to at: schismatic, drawback, hunan, apg, predominately, steed, learner, anecdotal,
# Nearest to is: triune, byrne, pistols, besht, part, cheaper, pentecostals, remedied,
# Nearest to often: ghee, imprint, grigory, federal, dinosaur, manufactures, spaniards, gas,
# Nearest to s: moldova, outbreak, porous, lm, disasters, gerrymandering, ourselves, bmi,
# Nearest to about: labours, isaak, dutch, witold, lookups, parton, rican, warplanes,
# Nearest to were: lekhanya, patriarchs, adalbert, cervantes, bandy, hunting, platonic, tsuburaya,
# Nearest to an: parliamentarism, el, wolff, tagline, undertakes, overly, omotic, sent,
# Nearest to war: herbicides, gigue, glorious, stand, impetuous, boost, rde, garb,
# Nearest to which: squid, si, symptoms, scarcely, lore, retailing, khayy, amillennialism,
# Average loss at step 2000: 4.372388
# Average loss at step 4000: 3.865085
# Average loss at step 6000: 3.787764
# Average loss at step 8000: 3.688097
# Average loss at step 10000: 3.614008
# Nearest to four: eight, six, five, seven, three, two, nine, zero,
# Nearest to who: he, and, also, diocese, often, enigmatic, ecoregion, which,
# Nearest to into: from, swampy, dacia, classmate, incrementally, dictation, divinely, nsg,
# Nearest to three: seven, five, eight, four, six, two, zero, nine,
# Nearest to and: or, who, tecumseh, s, gesta, in, like, of,
# Nearest to however: centre, pumice, when, trampled, islamic, bindusara, bef, treize,
# Nearest to been: were, akkadian, sardaukar, recalled, secures, cook, cofinal, hunters,
# Nearest to at: on, from, during, schismatic, selby, ablation, in, by,
# Nearest to is: was, are, has, judi, be, ef, bequest, elliptical,
# Nearest to often: it, also, who, manufactures, grigory, crayfish, pcb, sometimes,
# Nearest to s: his, and, cheeses, emory, intimately, or, neustadt, twayne,
# Nearest to about: isaak, lookups, pit, celebrating, witold, exhibiting, arin, on,
# Nearest to were: are, was, have, been, hoisted, would, monoxide, aq,
# Nearest to an: the, hoard, promiscuity, unoccupied, walrus, tailed, patriotism, rochelle,
# Nearest to war: badger, drip, stand, gigue, glorious, liberally, translator, cultural,
# Nearest to which: this, that, hypothetically, abeokuta, it, who, hohenzollern, also,
# Average loss at step 12000: 3.602367
# Average loss at step 14000: 3.567277
# Average loss at step 16000: 3.409730
# Average loss at step 18000: 3.458557
# Average loss at step 20000: 3.536294
# Nearest to four: three, six, seven, eight, five, nine, two, zero,
# Nearest to who: he, which, often, they, ecoregion, also, enigmatic, there,
# Nearest to into: from, kernow, dacia, swampy, divinely, through, pohjola, daniell,
# Nearest to three: four, two, five, seven, six, eight, nine, one,
# Nearest to and: or, which, but, from, including, nami, neuropsychological, coke,
# Nearest to however: but, when, pumice, treize, bindusara, investigate, mandriva, say,
# Nearest to been: be, were, labatt, already, akkadian, by, was, sardaukar,
# Nearest to at: in, from, on, dissolving, during, including, under, selby,
# Nearest to is: was, has, are, were, judi, be, flowering, echoing,
# Nearest to often: sometimes, also, widely, who, it, usually, crayfish, there,
# Nearest to s: exerting, analyzed, hitchhiker, arma, twayne, soo, cheeses, wittelsbach,
# Nearest to about: isaak, lookups, arin, skillfully, exhibiting, valpara, recompense, forty,
# Nearest to were: are, was, had, have, been, be, is, by,
# Nearest to an: the, parliamentarism, rochelle, promiscuity, unoccupied, walrus, contravariant, pep,
# Nearest to war: badger, drip, testament, urey, corrupted, impetuous, poee, translator,
# Nearest to which: that, who, this, it, there, but, also, and,
# Average loss at step 22000: 3.500938
# Average loss at step 24000: 3.491855
# Average loss at step 26000: 3.476930
# Average loss at step 28000: 3.475220
# Average loss at step 30000: 3.507403
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to who: he, they, she, often, which, enigmatic, many, and,
# Nearest to into: from, through, swampy, divinely, kernow, destroying, dictation, metaphorically,
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Nearest to and: or, but, in, of, however, who, while, olivine,
# Nearest to however: but, although, when, and, where, that, while, later,
# Nearest to been: be, were, was, become, akkadian, already, chittagong, yet,
# Nearest to at: in, on, during, after, when, fripp, qing, selby,
# Nearest to is: was, has, are, does, be, became, makes, had,
# Nearest to often: sometimes, also, usually, widely, still, now, there, who,
# Nearest to s: his, leben, unconditional, hitchhiker, exerting, gpled, intimately, arma,
# Nearest to about: isaak, on, forty, lookups, entire, skillfully, jdk, exhibiting,
# Nearest to were: are, was, have, had, been, be, many, bookrags,
# Nearest to an: rochelle, hoard, aclu, parliamentarism, daigo, provability, promiscuity, unoccupied,
# Nearest to war: finlay, badger, sergio, elaine, drip, urey, testament, satisfactorily,
# Nearest to which: this, that, it, who, where, but, there, also,
# Average loss at step 32000: 3.506042
# Average loss at step 34000: 3.489344
# Average loss at step 36000: 3.455201
# Average loss at step 38000: 3.301063
# Average loss at step 40000: 3.430289
# Nearest to four: six, five, eight, seven, three, two, nine, one,
# Nearest to who: he, which, often, she, they, also, ecoregion, dirham,
# Nearest to into: from, through, swampy, divinely, destroying, incrementally, dictation, daniell,
# Nearest to three: five, four, seven, two, six, eight, nine, zero,
# Nearest to and: or, but, including, replenished, knitting, while, which, excalibur,
# Nearest to however: but, although, while, when, statistically, call, that, though,
# Nearest to been: become, be, was, were, already, akkadian, sardaukar, yet,
# Nearest to at: on, in, selby, during, ablation, stumble, against, near,
# Nearest to is: was, are, has, judi, if, be, for, while,
# Nearest to often: sometimes, usually, also, widely, still, who, now, generally,
# Nearest to s: his, equestrian, sera, leben, arma, eyelashes, unconditional, vez,
# Nearest to about: on, forty, lookups, arin, celebrating, isaak, skillfully, wessel,
# Nearest to were: are, have, was, been, had, bookrags, be, including,
# Nearest to an: parliamentarism, rochelle, daigo, walrus, promenade, hoard, bonnie, seriously,
# Nearest to war: amplifier, finlay, drip, satisfactorily, sergio, badger, langdon, urey,
# Nearest to which: that, this, who, also, but, hydronium, often, there,
# Average loss at step 42000: 3.438953
# Average loss at step 44000: 3.459708
# Average loss at step 46000: 3.451044
# Average loss at step 48000: 3.353184
# Average loss at step 50000: 3.385606
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to who: he, which, she, also, often, they, never, ecoregion,
# Nearest to into: through, from, divinely, destroying, swampy, incrementally, kernow, classmate,
# Nearest to three: four, six, two, seven, five, eight, nine, zero,
# Nearest to and: or, but, including, however, while, of, iraqi, in,
# Nearest to however: but, although, while, when, that, where, though, and,
# Nearest to been: be, become, already, were, declined, was, had, akkadian,
# Nearest to at: during, near, ablation, against, from, on, stumble, in,
# Nearest to is: was, are, has, became, makes, be, involves, does,
# Nearest to often: sometimes, usually, still, generally, also, widely, now, commonly,
# Nearest to s: whose, entitles, attendants, apparition, giordano, gts, radbruch, arma,
# Nearest to about: palace, celebrating, on, isaak, parakeet, lookups, praetorian, wessel,
# Nearest to were: are, was, have, had, be, been, stadtholder, including,
# Nearest to an: hoard, daigo, rochelle, contravariant, parliamentarism, walrus, the, another,
# Nearest to war: sergio, urey, satisfactorily, finlay, drip, amplifier, badger, stealth,
# Nearest to which: that, this, also, who, where, what, often, tuatha,
# Average loss at step 52000: 3.435656
# Average loss at step 54000: 3.433103
# Average loss at step 56000: 3.444042
# Average loss at step 58000: 3.400589
# Average loss at step 60000: 3.392500
# Nearest to four: five, six, three, eight, seven, nine, two, one,
# Nearest to who: he, often, she, never, ecoregion, also, which, mineralogist,
# Nearest to into: through, from, divinely, towards, beyond, within, kernow, between,
# Nearest to three: four, five, six, seven, eight, two, nine, one,
# Nearest to and: or, but, including, however, although, than, switchable, lifeson,
# Nearest to however: but, although, though, when, that, and, which, while,
# Nearest to been: become, be, already, declined, were, was, akkadian, had,
# Nearest to at: during, in, near, on, rosetta, balts, stumble, after,
# Nearest to is: was, are, has, makes, judi, be, if, when,
# Nearest to often: sometimes, usually, also, now, generally, still, frequently, widely,
# Nearest to s: leben, unconditional, emory, giordano, whose, hitchhiker, subroutine, tooth,
# Nearest to about: wessel, palace, isaak, celebrating, lookups, pala, upon, on,
# Nearest to were: are, was, have, had, although, including, be, been,
# Nearest to an: daigo, parliamentarism, rochelle, hoard, harnesses, zubaydah, another, ratification,
# Nearest to war: sergio, finlay, badger, urey, drip, amplifier, designation, antietam,
# Nearest to which: that, this, but, what, where, it, however, situated,
# Average loss at step 62000: 3.237591
# Average loss at step 64000: 3.259113
# Average loss at step 66000: 3.402975
# Average loss at step 68000: 3.391471
# Average loss at step 70000: 3.358823
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to who: he, they, she, ecoregion, which, often, never, minigun,
# Nearest to into: through, from, divinely, within, towards, between, beyond, with,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to and: or, but, while, which, adamic, than, staggering, including,
# Nearest to however: but, although, though, while, that, where, when, which,
# Nearest to been: become, be, was, already, declined, were, had, yolande,
# Nearest to at: during, fetuses, after, around, emphasised, codebase, electroplating, in,
# Nearest to is: was, has, be, are, although, judi, does, being,
# Nearest to often: sometimes, usually, now, also, generally, still, commonly, frequently,
# Nearest to s: whose, leben, nac, hitchhiker, dervish, contesting, subroutine, neustadt,
# Nearest to about: upon, on, wessel, over, palace, isaak, recompense, pala,
# Nearest to were: are, have, was, had, be, while, been, including,
# Nearest to an: parliamentarism, rochelle, the, hoard, daigo, another, seriously, ratification,
# Nearest to war: sergio, finlay, drip, amplifier, designation, badger, urey, dail,
# Nearest to which: that, this, but, also, usually, what, often, actually,
# Average loss at step 72000: 3.379073
# Average loss at step 74000: 3.345653
# Average loss at step 76000: 3.319822
# Average loss at step 78000: 3.347342
# Average loss at step 80000: 3.372586
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to who: he, often, she, they, which, ecoregion, minigun, never,
# Nearest to into: through, towards, from, beyond, divinely, window, within, across,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to and: or, but, including, wheeler, than, while, undoing, posting,
# Nearest to however: but, although, though, while, that, where, when, which,
# Nearest to been: become, be, declined, already, were, was, yolande, aorist,
# Nearest to at: on, during, rangoon, near, in, around, after, rosetta,
# Nearest to is: was, has, are, became, although, includes, rterbuch, be,
# Nearest to often: sometimes, usually, commonly, still, generally, now, frequently, actually,
# Nearest to s: nac, remedied, gpled, neustadt, judith, subroutine, dervish, stds,
# Nearest to about: fathoms, wessel, over, highlights, celebrating, isaak, palace, recompense,
# Nearest to were: are, had, was, have, although, been, being, tend,
# Nearest to an: hoard, parliamentarism, contravariant, another, aclu, rochelle, hues, westcott,
# Nearest to war: finlay, sergio, designation, amplifier, dail, undergoing, satisfactorily, drip,
# Nearest to which: this, that, also, where, stad, usually, who, however,
# Average loss at step 82000: 3.407353
# Average loss at step 84000: 3.412583
# Average loss at step 86000: 3.386852
# Average loss at step 88000: 3.348180
# Average loss at step 90000: 3.367044
# Nearest to four: six, five, three, seven, eight, two, nine, one,
# Nearest to who: he, often, also, which, she, enigmatic, they, minigun,
# Nearest to into: through, from, divinely, within, between, window, towards, beyond,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to and: or, but, while, including, in, by, alzheimer, switchable,
# Nearest to however: but, although, though, while, that, where, since, karenina,
# Nearest to been: become, already, be, declined, was, akkadian, were, had,
# Nearest to at: during, near, under, florid, on, after, around, deadheads,
# Nearest to is: was, are, has, be, although, fridtjof, does, makes,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, still, also,
# Nearest to s: leben, whose, hitchhiker, his, eapc, gpled, attendants, apparition,
# Nearest to about: celebrating, over, fathoms, wessel, palace, parakeet, recompense, arin,
# Nearest to were: are, had, was, have, although, while, these, been,
# Nearest to an: contravariant, walrus, daigo, another, parliamentarism, hoard, rochelle, sidelines,
# Nearest to war: designation, finlay, sergio, undergoing, dhrystone, dail, amplifier, urey,
# Nearest to which: that, this, also, what, usually, isolates, these, often,
# Average loss at step 92000: 3.399265
# Average loss at step 94000: 3.251946
# Average loss at step 96000: 3.354321
# Average loss at step 98000: 3.241987
# Average loss at step 100000: 3.357553
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to who: he, she, actually, often, named, never, enigmatic, also,
# Nearest to into: through, from, divinely, towards, beyond, within, between, around,
# Nearest to three: four, two, five, six, seven, eight, nine, one,
# Nearest to and: or, but, while, including, although, posting, like, when,
# Nearest to however: but, although, though, that, while, where, especially, which,
# Nearest to been: become, already, be, declined, was, recently, duquette, akkadian,
# Nearest to at: during, on, after, in, near, fetuses, florid, vesque,
# Nearest to is: was, has, are, judi, be, became, becomes, godel,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, still, typically,
# Nearest to s: gpled, whose, leben, his, alessandro, apparition, the, tombs,
# Nearest to about: celebrating, on, around, wessel, pala, approximately, parakeet, palace,
# Nearest to were: are, was, have, had, these, those, include, although,
# Nearest to an: another, daigo, contravariant, rochelle, parliamentarism, walrus, fracture, ystok,
# Nearest to war: designation, dhrystone, finlay, sergio, satisfactorily, amplifier, urey, drip,
# Nearest to which: that, this, what, usually, actually, it, however, these,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
