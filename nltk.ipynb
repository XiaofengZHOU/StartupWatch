# %%
import nltk
import json

import json
f=open('data/data.json','r')
articles = json.load(f)    
f.close()

    
article = articles[key][3]
content = article["content"]
tokens = nltk.word_tokenize(content)
tagged = nltk.pos_tag(tokens)
entities = nltk.chunk.ne_chunk(tagged)
print(content)

# %%
nltk.help.upenn_tagset()

# %%
import nltk
from nltk.corpus import brown
news_text = brown.words(categories='news')
news_text[0:2]
# Out:
# ['The', 'Fulton']

# %%
from bs4 import BeautifulSoup
from crawlers.tools import get_html_doc
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk

url = 'http://www.techworld.com/picture-gallery/startups/14-of-best-robotics-startups-in-uk-3654908/'
html_doc = get_html_doc(url)
soup = BeautifulSoup(html_doc, 'html.parser')
raw = BeautifulSoup(html_doc).get_text()
tokens = nltk.word_tokenize(raw)
sent_tokenize(raw)
# Out:
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\xizhou\appdata\local\programs\python\python36-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))
# ['\n\n\n14 of the best robotics startups in the UK | Techworld\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n{\n"@context" : "http://schema.org",\n"@type" : "Organization",\n"name" : "Techworld",\n"url" : "http://www.techworld.com/",\n"potentialAction": {\n"@type": "SearchAction",\n"target": "http://www.techworld.com/search/?q={search}",\n"query-input": "required name=search"\n},\n"sameAs" : [\n"https://www.facebook.com/TechworldUK",\n"https://twitter.com/TechworldNews",\n"https://plus.google.com/+TechworldUK/",\n"https://www.linkedin.com/company/techworld"\n]\n}\n\n\n\n\n\n\nvar require = {\nbaseUrl: "//cdn1.techworld.com/scripts-dist/",\nwaitSeconds: 15,\nurlArgs : \'bust=\' + \'1494327436JS_20170509125021\'\n};\n\n\n\n\n \n \n\n\n//fallback just in case console is used and left in\nif(typeof window.console === \'undefined\' && typeof console.firebug === \'undefined\'){\nvar names = ["log", "debug", "info", "warn", "error", "assert", "dir", "dirxml",\n"group", "groupEnd", "time", "timeEnd", "count", "trace", "profile", "profileEnd"];\nwindow.console = {};\nfor (var i = 0; i < names.length; ++i)\nwindow.console[names[i]] = function() {}\n}\n\n\nvar setting = function(key){\nvar settings = {\nADS_TAKEOVER_TARGETING: true\n};\nreturn settings[key];\n};\n\n\nvar setting = (function(oldSettingFunc){\nreturn function(key){\nvar AD_SETTINGS = {\nPLEASEWAIT_IMG: \'//cdn2.techworld.com/graphics/loading_tw_large.gif\',\nLIVEFYRE: true,\nLIVEFYRE_DEBUG: true,\nLIVEFYRE_TOKEN_COOKIE: \'lft\',\nWEBMASTEREMAIL: \'webmaster@techworld.com\',\nUSER_DEBUG: true,\nBOOMTRAIN_DEBUG: false,\nREGISTER_USER_EVENT: \'open-register-ui\',\nUSER_OVERLAY_EVENT: \'open-user-ui\',\nSOCIALAUTH_ERROR_EVENT: \'open-social-auth-error-ui\',\nCOMMENT_REG_PROMPT_KEY: \'comment_reg_prompt\',\nSITE_LOGIN_EVENT: \'site-login-complete\',\nBLITZEN_NEWSLETTER_REGISTRATION_FORM_URL: \'https://idg.blitzen.com/form/techworld\',\nBLITZEN_NEWSLETTER_REGISTRATION_FORM_ID: \'5968535b9727a6d2d31d9edcea3033\',\nGOOGLE_RECAPTCHA_SITE_KEY: \'6Le0CAwUAAAAAGpUM2U_B1t4kS1LGsTJMZCp9ARw\'\n};\nreturn typeof AD_SETTINGS[key] !== \'undefined\' ?',
#  "AD_SETTINGS[key] : oldSettingFunc(key);\n};\n})(setting);\n\n\n(function() {\nvar cx = '015931524915905697068:huw-m0shsv8';\nvar gcse = document.createElement('script');\ngcse.type = 'text/javascript';\ngcse.async = true;\ngcse.src = (document.location.protocol == 'https:' ?",
#  "'https:' : 'http:') +\n'//www.google.com/cse/cse.js?cx=' + cx;\n// gcse.src = (document.location.protocol == 'https:' ?",
#  "'https:' : 'http:') +\n'//www.google.com/cse/cse.js?'",
#  '+ ((window.Device.isMobile)?',
#  "'mob=1&':'') + 'cx=' + cx;\nvar s = document.getElementsByTagName('script')[0];\ns.parentNode.insertBefore(gcse, s);\n})();\n\n\nwindow.$geoLocationDef = $.Deferred();\nrequire(['jstorage'], function() {\nvar GEO_LOC_KEY = 'GEO_LOC_DATA',\nGEO_LOC_TTL = 3600000,\ngeolocData = $.jStorage.get(GEO_LOC_KEY);\nif((typeof geolocData === 'undefined') || (geolocData === null)){\n$.ajax({\nurl: '/coldboxproxy.cfc',\ndata: {\n'method': 'getGeoLocation'\n},\ndataType: 'json'\n}).done(function(data, textStatus, jqXHR){\n//console.log('GeoLoc from web service',data);\nif('statusCode' in data && data.statusCode == 'OK'){\n$.jStorage.set(GEO_LOC_KEY, data, {TTL: GEO_LOC_TTL});\nwindow.$geoLocationDef.resolve();\n}\n});\n}else{\nwindow.$geoLocationDef.resolve();\n}\n});\n\n \n\nvar AD_CONFIG_UNITS = {},\nconfigureAdUnits = function(){throw('not defined yet');};\n(function(){\nconfigureAdUnits = function() {\nif(adConfig.debug)console.log('configureAdUnits called');\nvar mappings = {\nwelcomead: googletag.sizeMapping().",
#  'addSize([650, 0], [1, 1]).',
#  'addSize([320, 0], [1, 1]).',
#  'addSize([0, 0], []).',
#  'build(),\nleaderboard: googletag.sizeMapping().',
#  'addSize([980, 0], [[970, 250], [728, 90]]).',
#  'addSize([570, 0], [[728, 90]]).',
#  'addSize([478, 0], [[320, 50], [300, 50], [300, 250], [468, 60]]).',
#  'addSize([280, 0], [[320, 50], [300, 50], [300, 250]]).',
#  'addSize([0, 0], []).',
#  'build(),\nleaderboardMobile: googletag.sizeMapping().',
#  'addSize([830, 0], []).',
#  'addSize([570, 0], []).',
#  'addSize([478, 0], [[468, 60]]).',
#  'addSize([0,0], [[320, 50], [300, 50], [300, 250]]).',
#  'build(),\nsmallLeaderboard: googletag.sizeMapping().',
#  'addSize([980, 0], [[728, 90]]).',
#  'addSize([570, 0], [[728, 90]]).',
#  'addSize([478, 0], [[468, 60]]).',
#  'addSize([280, 0], [[320, 50], [300, 50], [300, 250]]).',
#  'addSize([0, 0], []).',
#  'build(),\nfixedSidebarMpu: googletag.sizeMapping().',
#  'addSize([window.breakpoints.tabletPortrait, 0], [[300, 250], [300, 600], [300, 125]]).',
#  'addSize([0, 0], []).',
#  'build(),\nmpu: googletag.sizeMapping().',
#  'addSize([830, 0], [[300, 250], [300, 600], [300, 500]]).',
#  'addSize([320, 0], [[300, 250]]).',
#  'addSize([0, 0], []).',
#  'build(),\nmpuSmall: googletag.sizeMapping().',
#  'addSize([830, 0], [[300, 250]]).',
#  'addSize([320, 0], [[300, 250],[320, 50]]).',
#  'addSize([0, 0], []).',
#  'build(),\nmpuMobile: googletag.sizeMapping().',
#  'addSize([830, 0], []).',
#  'addSize([570, 0], []).',
#  'addSize([320, 0], [[300, 250]]).',
#  'addSize([0, 0], []).',
#  'build(),\ntwoXtwo: googletag.sizeMapping().',
#  'addSize([0,0], [[2,2]]).',
#  'build(),\nfourXone: googletag.sizeMapping().',
#  'addSize([0,0], [[4,1]]).',
#  'build(),\n//sharethrough\nsharethrough: googletag.sizeMapping().',
#  'addSize([0,0], [[2,3]]).',
#  'build(),\nsharethroughRHC: googletag.sizeMapping().',
#  'addSize([0,0], [[2,3]]).',
#  'build(),\nsharethroughLatest: googletag.sizeMapping().',
#  'addSize([0,0], [[2,3]]).',
#  'build(),\nsharethroughInArticle: googletag.sizeMapping().',
#  'addSize([0,0], [[2,3]]).',
#  'build(),\navid: googletag.sizeMapping().',
#  'addSize([0,0], [[2,1]]).',
#  'build(),\nsixFortyXFourEighty: googletag.sizeMapping().',
#  'addSize([650, 0], [[640, 480]]).',
#  'addSize([320, 0], [[320, 480]]).',
#  'build(),\nspringboard: googletag.sizeMapping().',
#  'addSize([970,0], [[970,150]]).',
#  'build()\t\n};\nvar slotSize = {\nleaderboard: [728, 90],\nleaderboardMobile: [320, 50],\nsmallLeaderboard: [728, 90],\nfixedSidebarMpu: [300, 250],\nmpu: [300, 250],\nmpuSmall: [300, 250],\nmpuMobile: [300, 250],\ntwoXtwo: [2, 2],\nfourXone: [4, 1],\navid: [2, 1],\nsharethrough: [2,3],\nsharethroughRHC: [2,3],\nsharethroughLatest: [2,3],\nsharethroughInArticle: [2,3],\nsixFortyXFourEighty: [320, 480],\nspringboard: [970,150]\n};\nif(adConfig.debug)console.log(\'adding welcomead to unit config\');\nAD_CONFIG_UNITS["welcomead"] = {count: 1, mappings: mappings[\'welcomead\'], slotSize: slotSize[\'welcomead\']};\nif(adConfig.debug)console.log(\'adding mpu to unit config\');\nAD_CONFIG_UNITS["mpu"] = {count: 0, mappings: mappings[\'mpu\'], slotSize: slotSize[\'mpu\']};\nif(adConfig.debug)console.log(\'adding sixFortyXFourEighty to unit config\');\nAD_CONFIG_UNITS["sixFortyXFourEighty"] = {count: 1, mappings: mappings[\'sixFortyXFourEighty\'], slotSize: slotSize[\'sixFortyXFourEighty\']};\nif(adConfig.debug)console.log(\'adding sharethroughRHC to unit config\');\nAD_CONFIG_UNITS["sharethroughRHC"] = {count: 0, mappings: mappings[\'sharethroughRHC\'], slotSize: slotSize[\'sharethroughRHC\']};\nif(adConfig.debug)console.log(\'adding smallLeaderboard to unit config\');\nAD_CONFIG_UNITS["smallLeaderboard"] = {count: 0, mappings: mappings[\'smallLeaderboard\'], slotSize: slotSize[\'smallLeaderboard\']};\nif(adConfig.debug)console.log(\'adding mpuSmall to unit config\');\nAD_CONFIG_UNITS["mpuSmall"] = {count: 0, mappings: mappings[\'mpuSmall\'], slotSize: slotSize[\'mpuSmall\']};\nif(adConfig.debug)console.log(\'adding sharethrough to unit config\');\nAD_CONFIG_UNITS["sharethrough"] = {count: 0, mappings: mappings[\'sharethrough\'], slotSize: slotSize[\'sharethrough\']};\nif(adConfig.debug)console.log(\'adding fixedSidebarMpu to unit config\');\nAD_CONFIG_UNITS["fixedSidebarMpu"] = {count: 1, mappings: mappings[\'fixedSidebarMpu\'], slotSize: slotSize[\'fixedSidebarMpu\']};\nif(adConfig.debug)console.log(\'adding fourXone to unit config\');\nAD_CONFIG_UNITS["fourXone"] = {count: 1, mappings: mappings[\'fourXone\'], slotSize: slotSize[\'fourXone\']};\nif(adConfig.debug)console.log(\'adding avid to unit config\');\nAD_CONFIG_UNITS["avid"] = {count: 1, mappings: mappings[\'avid\'], slotSize: slotSize[\'avid\']};\nif(adConfig.debug)console.log(\'adding sharethroughInArticle to unit config\');\nAD_CONFIG_UNITS["sharethroughInArticle"] = {count: 0, mappings: mappings[\'sharethroughInArticle\'], slotSize: slotSize[\'sharethroughInArticle\']};\nif(adConfig.debug)console.log(\'adding mpuMobile to unit config\');\nAD_CONFIG_UNITS["mpuMobile"] = {count: 0, mappings: mappings[\'mpuMobile\'], slotSize: slotSize[\'mpuMobile\']};\nif(adConfig.debug)console.log(\'adding leaderboard to unit config\');\nAD_CONFIG_UNITS["leaderboard"] = {count: 1, mappings: mappings[\'leaderboard\'], slotSize: slotSize[\'leaderboard\']};\nif(adConfig.debug)console.log(\'adding leaderboardMobile to unit config\');\nAD_CONFIG_UNITS["leaderboardMobile"] = {count: 0, mappings: mappings[\'leaderboardMobile\'], slotSize: slotSize[\'leaderboardMobile\']};\nif(adConfig.debug)console.log(\'adding springboard to unit config\');\nAD_CONFIG_UNITS["springboard"] = {count: 0, mappings: mappings[\'springboard\'], slotSize: slotSize[\'springboard\']};\nif(adConfig.debug)console.log(\'adding twoXtwo to unit config\');\nAD_CONFIG_UNITS["twoXtwo"] = {count: 0, mappings: mappings[\'twoXtwo\'], slotSize: slotSize[\'twoXtwo\']};\nif(adConfig.debug)console.log(\'adding sharethroughLatest to unit config\');\nAD_CONFIG_UNITS["sharethroughLatest"] = {count: 0, mappings: mappings[\'sharethroughLatest\'], slotSize: slotSize[\'sharethroughLatest\']};\nif(adConfig.debug)console.log(\'configureAdUnits returning\');\nreturn AD_CONFIG_UNITS;\n};\n})();\n\n \n\n\n\ngoogletag = window.googletag || {cmd:[]};\nvar refreshAds = function(adIds) {\nvar adArr = [],\nadIdsInArr = [];\nif(typeof adIds !== \'undefi ...
#  '*)\', \'i\').test(key)){\nadIdsInArr.push(key);\nreturn value;\n}\n});\n}\nif(adConfig.debug)console.log(\'refreshAds() called for\', arguments, adIdsInArr, adArr);\ngoogletag.pubads().refresh(adArr);\n}\n\n\ngoogletag = window.googletag || {cmd:[]};\nvar setting = (function(oldSettingFunc){\nreturn function(key){\nvar AD_SETTINGS = {\n"INDEX_MEDIA_ADS": false\n};\nreturn typeof AD_SETTINGS[key] !== \'undefined\' ?',
#  "AD_SETTINGS[key] : oldSettingFunc(key);\n};\n})(setting);\n/*\n* polyfill for Object.keys\n* From https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object/keys\n*/\nif (!Object.keys) {\nObject.keys = (function () {\n'use strict';\nvar hasOwnProperty = Object.prototype.hasOwnProperty,\nhasDontEnumBug = !",
#  '({toString: null}).propertyIsEnumerable(\'toString\'),\ndontEnums = [\n\'toString\',\n\'toLocaleString\',\n\'valueOf\',\n\'hasOwnProperty\',\n\'isPrototypeOf\',\n\'propertyIsEnumerable\',\n\'constructor\'\n],\ndontEnumsLength = dontEnums.length;\nreturn function (obj) {\nif (typeof obj !== \'object\' && (typeof obj !== \'function\' || obj === null)) {\nthrow new TypeError(\'Object.keys called on non-object\');\n}\nvar result = [], prop, i;\nfor (prop in obj) {\nif (hasOwnProperty.call(obj, prop)) {\nresult.push(prop);\n}\n}\nif (hasDontEnumBug) {\nfor (i = 0; i < dontEnumsLength; i++) {\nif (hasOwnProperty.call(obj, dontEnums[i])) {\nresult.push(dontEnums[i]);\n}\n}\n}\nreturn result;\n};\n}());\n};\nvar gptEscape = function(s){\ns = s.replace(/[^a-zA-Z0-9,_\\- ]/gim,\'\');\n//s = s.replace(/[ ]+/gi,\'+\');//replace multi space with +\nreturn s;\n};\nvar adConfig = {\ndebug : false,\nzone : \'picture-gallery_section\'.toLowerCase(),\nunits : AD_CONFIG_UNITS,\nadsToRefresh : {},\nmpuCount : 0,\ncurrentUrl : encodeURIComponent(window.location.href),\natf: 0,\nbtf: 0\n};\nif(adConfig.debug)console.log(adConfig);\nvar setupTargetingKeyPairs = function(){\nif(typeof setting !== \'undefined\'){\nvar takeoverTargeting = setting(\'ADS_TAKEOVER_TARGETING\');\nif(typeof takeoverTargeting !== \'undefined\' && takeoverTargeting){\ngoogletag.pubads().setTargeting("takeover", (Math.random() * 100 <= 50).toString());\n}\n}\ngoogletag.pubads().setTargeting("URL", adConfig.currentUrl);\n//if boolean and true or if not and has content show --->\n//if boolean and true or if not and has content show --->\n//if boolean and true or if not and has content show --->\ngoogletag.pubads().setTargeting(\'stg\', gptEscape(\'false\'));\nif(adConfig.debug)console.log(\'stg=\'+gptEscape(\'false\'));\n//if boolean and true or if not and has content show --->\ngoogletag.pubads().setTargeting(\'hline\', gptEscape(\'Who are the hottest robotics startups in the UK Meet 14 of the countrys best\'));\nif(adConfig.debug)console.log(\'hline=\'+gptEscape(\'Who are the hottest robotics startups in the UK Meet 14 of the countrys best\'));\n};\nvar setupKeywordTargeting = function(metatags){\nmetatags = metatags || jQuery(\'meta[name=keywords]\').attr("content");\n//meta tags\nvar rs_tax = [];\nif (metatags != undefined && metatags != \'\') {\nstrmetatags = metatags.toLowerCase().replace(/&amp;/g, "").replace(/&/g, "").split(",");\nfor(var i=0,len=strmetatags.length; value=strmetatags[i], i<len; i++) {\nrs_tax.push(gptEscape(jQuery.trim(value)));\n}\n}\nif (rs_tax.length > 0) {\nif(adConfig.debug)console.log(\'kw=\' + rs_tax.join(\',\'));\ngoogletag.pubads().setTargeting("kw", rs_tax);\n}\n};\nvar setupResizeAction = function(){\nvar resizeTimeOut = false;\nvar windowWidthVal = jQuery( window ).width();\nif(windowWidthVal<570){\n$(window).on("orientationchange",function(){\nrefreshAds();\n});\n}else{\n}\n}\n\n\nvar setupAmazonAdTargeting = function(){\nif(typeof amznads !== \'undefined\') {\ntry {\namznads.setTargetingForGPTAsync(\'amznslots\');\n}catch(ex){\nconsole.error(ex);\n}\n}else if(adConfig.debug){\nif(adConfig.debug)console.log(\'amznads is undefined\');\n}\n};\n\n\nvar setupSearchTargeting = function(){\nif(adConfig.debug)console.log(\'no search term\');\n};\n\n\nvar setupArticleTargeting = function(){\ngoogletag.pubads().setTargeting("artid", \'3654908\');\nif(adConfig.debug)console.log(\'artid=3654908\');\n};\n\n\nfunction getUrlVars() {\nvar vars = {};\nvar parts = window.location.href.replace(/[?&]+([^=&]+)=([^&]*)/gi, function(m,key,value) {\nvars[key] = value;\n});\nreturn vars;\n}\nif(adConfig.debug)console.log(adConfig);\ngoogletag.cmd.push(function() {\nif(adConfig.debug)console.log(\'Ads Starting ad configuration\');\nconfigureAdUnits();\ngoogletag.pubads().collapseEmptyDivs();\ngoogletag.pubads().enableAsyncRendering();\ngoogletag.pubads().enableVideoAds();\nwindow.addAdSlot = function(adId, adUnitName, adSlotSize, adMappings, targetPrefix){\nif(ad ...
#  "-5 : 0) + (b.indexOf('leaderboard') == 0 ?",
#  '5 : 0));\n});\nif(adConfig.debug)console.log(\'Defining ad slots>>\');\nfor(var adName in adUnits){\nvar adName = adUnits[adName]\nif(adName.indexOf(\'welcomead\') >= 0 && true){\nif(adConfig.debug)console.log(\'enabling welcomead\');\nvar ad = googletag.defineOutOfPageSlot(slotPrefix + adConfig.zone, \'welcomead-pos1\')\n.defineSizeMapping(AD_CONFIG_UNITS["welcomead"].mappings)\n.addService(googletag.pubads());\npubAds.push(ad);\nadConfig.adsToRefresh[adName] = ad;\ncontinue;\n}\nvar adIdPrefix = adName + \'-pos\',\nadUnitName = slotPrefix + adConfig.zone,\nadCount = adConfig.units[adName].count,\nadMappings = adConfig.units[adName].mappings,\nj=0,\nadSlotSize = adConfig.units[adName].slotSize;\nvar adPrefixVal = \'\';\nif (typeof getUrlVars()[\'prefix\'] != \'undefined\') {\nadPrefixVal = getUrlVars()[\'prefix\'];\n}\nvar targetPrefix = \'\';\nfor(var i=1; i <=adCount; i++){\nif(adConfig.debug)console.log(\'attempting to enable \'+adName + \' @ pos=\'+i+\' with \', adConfig.units[adName]);\n++j;\nif([\'leaderboard\', \'sky\', \'mpu\', \'mpuSmall\', \'mpuSky\', \'mpuSmallSky\', \'fixedSidebarMpu\'].indexOf(adName) > -1){\nif(i==1 && ([\'mpuSmall\', \'mpuSky\', \'mpuSmallSky\'].indexOf(adName) == -1)){\ntargetPrefix = \'atf1\';\nadConfig.atf++;\nj=0;\n}else {\nj = (targetPrefix==\'atf2\') ?',
#  "1 : j;\ntargetPrefix = 'btf'+j;\nif(adName.indexOf('mpu') > -1){ \nadConfig.btf++;\n}\n}\n}\nvar adId = adIdPrefix+i,\nsetupArgs = [adId, adUnitName, adSlotSize, adMappings];\nif(['leaderboard', 'sky', 'mpu', 'mpuSmall', 'mpuSky', 'mpuSmallSky', 'fixedSidebarMpu'].indexOf(adName) > -1){\nsetupArgs.push(targetPrefix);\n}\nvar ad = addAdSlot.apply(this, setupArgs);\npubAds.push(ad);\nif(adConfig.debug)console.log('enabled '+adName+' with ', adUnitName, adSlotSize, adMappings, adId, 'pos='+i);\n}\n}\nif(adConfig.debug)console.log('Finished defining ad slots');\nsetupResizeAction();\nsetupKeywordTargeting();\nsetupSearchTargeting();\nsetupArticleTargeting();\nsetupTargetingKeyPairs();\nsetupAmazonAdTargeting();\ngoogletag.pubads().disableInitialLoad();//enable with proximic call back\ngoogletag.pubads().enableSingleRequest();\ngoogletag.enableServices();\nif(adConfig.debug)console.log('Finished ad configuration');\n});\n$(document).ready(function(){\ngoogletag.cmd.push(function(){\nif(adConfig.debug)console.log('calling ad refresh');\nif(typeof headertag !== 'undefined'){\nheadertag.pubads().refresh();\n}else{\ngoogletag.pubads().refresh();\n}\n});\n});\n\n \n\n!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?",
#  "n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;\nn.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;\nt.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,\ndocument,'script','https://connect.facebook.net/en_US/fbevents.js');\nfbq('init', '252017708599048'); // Insert your pixel ID here.",
#  'fbq(\'track\', \'PageView\');\n\n\n\n\n \n \n\ndataLayer = [{"Content Type":"Slideshow","Primary Channel":"Startups","Published Day":"10","Is Original UK Content":"Yes","Content Author":"Thomas Macaulay","Is Commercial":"No","Is Article":"Yes","Feature Category":"Features","Channels":"Personal Tech,Startups","Published Month":"May","Date Published":"10 May 2017","Is UK Author":"Yes","Published Year":"2017","All":"fc-Features,pch-Startups,aut-Thomas Macaulay,cs-Techworld,ct-Slideshow,Is UK Author,Is Original UK Content,ch-Personal Tech,ch-Startups,Is Article","Content Origin":"Techworld"}];\n\n\n\nvar _sf_startpt=(new Date()).getTime()\n\n\nvar id = \'welcomead-pos1\';\nvar type = \'welcomead\';\nif(adConfig.debug)console.log(\'ad.cfm id = \',id,\' type = \',type);\nif(type === \'mpu\' && Device.isMobile && adConfig.mpuCount < 2){\nadConfig.mpuCount += 1;\nif(adConfig.debug)console.log(\'adConfig.mpuCount\',adConfig.mpuCount,\'adType\',\'welcomead\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'welcomead-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}else if(type === \'mpu\' && Device.isMobile && adConfig.mpuCount >= 2){\nif(adConfig.debug)console.log(\'nothing\');\n}else{\nif(adConfig.debug)console.log(\'adConfig.mpuCountX\',adConfig.mpuCount,\'adType\',\'welcomead\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'welcomead-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}\n\n\n \n\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?',
#  "'&l='+l:'';j.async=true;j.src=\n'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,'script','dataLayer','GTM-P95BHX');\n \n\n\n\n\n\n\n\n\nvar id = 'leaderboard-pos1';\nvar type = 'leaderboard';\nif(adConfig.debug)console.log('ad.cfm id = ',id,' type = ',type);\nif(type === 'mpu' && Device.isMobile && adConfig.mpuCount < 2){\nadConfig.mpuCount += 1;\nif(adConfig.debug)console.log('adConfig.mpuCount',adConfig.mpuCount,'adType','leaderboard','Device.isMobile',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = 'leaderboard-pos1';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log('rendering ad id = ' + id);\ngoogletag.display(id);\n}\n});\n}else if(type === 'mpu' && Device.isMobile && adConfig.mpuCount >= 2){\nif(adConfig.debug)console.log('nothing');\n}else{\nif(adConfig.debug)console.log('adConfig.mpuCountX',adConfig.mpuCount,'adType','leaderboard','Device.isMobile',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = 'leaderboard-pos1';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log('rendering ad id = ' + id);\ngoogletag.display(id);\n}\n});\n}\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechworld\n\n\n\nFeatures\n\n\nTechnology\n\n\nInnovation\n\n\nJobs\n\n\n\n\nFeatures\n\nAll Features\nNews\nAnalysis\n\n\n\nTechnology\n\nSecurity\nApps\nMobile\nNetworking\nBig Data\nStorage\nOperating Systems\n\n\n\nInnovation\n\nStartups\nWearables\nCloud\nSocial Media\nUser Experience\nE-Commerce\n\n\n\nTutorials\n\n\nIndustries\n\nTravel & Leisure\nFinancial Services\nRetail\nPublic Sector\nManufacturing\nCreative & Media\nAutomotive\n\n\n\nResources\n\nGalleries\nDownloads\nWhite Papers\nEvents\n\n\n\nJobs\n\nTech Career Advice\nLatest Tech Jobs\n\n\n\nTechies\n\n\n\n\n(function($){\nwindow.$userLinksDef = $.Deferred();\nrequire(['userLinks']);\n})($);\n\n\n\n\n\n\n\n\n\n\n\n\nsetTimeout(function(){\n$('#topSearchContainer .gsc-input input.gsc-input').attr('placeholder','Search');\n}\n, 3000);\n\n\n\n\ntw\nin\nfb\ngplus\njobbio\n\nNewsletter\n\n(function(){\nvar toExec = function($, ouibounce){\nif(typeof window.ouibounce === 'undefined' && typeof arguments[1] !== 'undefined'){\nwindow.ouibounce = ouibounce;\n}\nvar $btn = $('#newsletter-signup-btn--469CA7AC-9304-42DA-9220A585BBE48D27 .newsletter-signup-btn__btn:not([data-has-trigger])');\n$btn.attr('data-has-trigger', 'true');\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - attaching event listener to sign up button', arguments);\n$btn.on('click', null, null, function(e){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - opening form', arguments);\ne.preventDefault();\n$btn.addClass('newsletter-signup-btn__btn--loading');\nwindow.idguk.blitzen.openNewsletterSignUpForm();\nvar checkCount = 0,\ncheckInterval;\ncheckInterval = setInterval(function(){\ncheckCount++;\nvar $iframe = $('#' + setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID')),\nclearIt = false;\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - loading check', $iframe);\nif($iframe.length){\nif($iframe.attr('data-loaded') == 1){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - loading check - clearing', $iframe, checkCount);\nclearIt = true;\n}else{\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - loading check - not loaded', $iframe, checkCount);\n}\n}else{\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - loading check - iframe not found', $iframe, checkCount);\n}\nif(clearIt || checkCount > 10){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - loading check - clearing interval', $iframe, checkCount);\n$btn.removeClass('newsletter-signup-btn__btn--loading');\nclearInterval(checkInterval);\n}\n}, 1000);\n});\n};\nif((typeof require !== 'undefined')){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up button - found require');\nrequire(['jquery', 'blitzenForm'], toExec);\n}else if(typeof idguk.r ...
#  "Meet 14 of the country's best\n\n\n\n\n\n\n\n\n\n\n\nThomas Macaulay\nTom is online editor.",
#  'He studied English Literature and History at Sussex University before gaining a Masters in Newspaper Journalism from City University.',
#  "He's particularly interested in the public sector and the ethical implications of emerging technologies.",
#  'By\nThomas Macaulay\n\n| May 10, 2017\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n(function () {\nvar f = function(evt){\nvar authorName = \'Thomas Macaulay\';\nvar featureCategoryName = \'Features\';\nvar itemType = \'Slideshow\';\nvar service = $(evt.target).text();\nvar eventLabel = service+\',\'+authorName+\',\'+itemType+\',\'+featureCategoryName;\nvar shareUrl = \'\';\nvar shareText = $(this).attr(\'st_title\');\nswitch ($(this)[0].id){\ncase \'st_twitter\':\nshareUrl = \'https://twitter.com/intent/tweet?text=\' + shareText + \'&via=techworldnews\' + \'&url=\' + $(location).attr(\'href\');\nbreak;\ncase \'st_facebook\':\nshareUrl = \'https://www.facebook.com/sharer/sharer.php?&u=\' + $(location).attr(\'href\');\nbreak;\ncase \'st_linkedin\':\nshareUrl = \'http://www.linkedin.com/shareArticle?mini=true&title=\' + shareText + \'&url=\' + $(location).attr(\'href\');\nvar desc = $(\'meta[name=description]\').attr("content");\nif(typeof desc === \'string\'){\nshareUrl = shareUrl + \'&summary=\' + desc;\n}\nbreak;\ncase \'st_googleplus\':\nshareUrl = \'https://plus.google.com/share?url=\'+ $(location).attr(\'href\');\nbreak;\ndefault:\nbreak;\n}\n$(\'#shareUrl\').attr(\'href\',shareUrl);\n$(\'#shareUrl\')[0].click();\n//console.log(\'social icons click\',eventLabel);\ndataLayer.push({\'event\':\'GAevent\', \'eventCategory\':\'User Activity\', \'eventAction\':\'Shared\',\'eventLabel\':eventLabel});\n}\n$(function() {\n$(\'.shareIcon\').on("click", f);\n});\n}());\n\n\nShare \n\nTwitter\nFacebook\nLinkedIn\nGoogle Plus\n\n\nThe UK has provided a loving home for robots ever since Captain Richards & A.H. Reffell built one of the world’s first in 1928.',
#  '"Eric" is now reborn following a Kickstarter campaign to bring him back to life and has been given a starring role in a new\xa0exhibition at London’s Science Museum.',
#  'The country’s startups are ensuring he won’t be lonely in future.',
#  'The robotics market is set to reach $226 billion worldwide by 2021,\xa0according to market intelligence company Tractica, more than six times its current value.',
#  'Research by CB Insights\xa0suggests British startups currently account for six percent of the global market, but a growing ecosystem of ambitious visionaries supported by the\xa0recently-announced £17.3\xa0million of funding from\xa0the government\xa0means many are well-positioned to become world-leaders in the sector.',
#  '1.',
#  'Best robotics startups in the UK: Generic Robots\n\n\n\n\n\n\n\n\n© Generic Robots\n\n\n\nReading-based startup Generic Robots\xa0works on technology that lets users\xa0create, feel, manipulate or alter simulated 3D objects in a virtual environment.',
#  "The\xa0team is building the world's first general purpose simulated training platform for\xa0dentists and doctors with this tech.",
#  'The SimuTouch\xa0system is designed to provide a safe and versatile way to learn\xa0complex clinical procedures.',
#  "They've also\xa0designed a platform to bring the technology to the masses, with potential applications for haptic VR in fields from gaming to education.",
#  'The company has been developing its technology for more than ten years, and its dental training simulator is already in use at Kings College London.',
#  'It recently raised £251,746 from the SyndicateRoom investment platform.',
#  '2.',
#  'Best robotics startups in the UK: Cambridge Medical Robotics\n\n\n\n\n\n\n\n\n© Cambridge Medical Robotics\n\n\n\nMinimally invasive surgery tends to be a highly expensive procedure, but Cambridge Medical Robotics is developing a next-generation robotic system that could make it affordable and universally accessible.',
#  'The startup has already successfully tested the performance of the platform on cadavers.',
#  'The big plans\xa0have already attracted big backing.',
#  'In July 2016, the company raised $20.3 million in a Series A funding round from investors including ABB Technology Ventures, LGT Global Invest and Cambridge Innovation Capital.',
#  '3.',
#  'Best robotics startups in the UK: Automata Technologies\n\n\n\n\n\n\n\n\n© Automata Technologies\n\n\n\nLondon-based startup\xa0Automata\xa0was founded in January 2015\xa0to democratise robotics by lowering costs and improving usability.',
#  'The company plans\xa0to use a robotics-as-a-service (RAAS) business model\xa0to integrate robotics into existing workflows more efficiently and to bring automation to new markets.',
#  'Automata has attracted an undisclosed quantity of funding from ABB Technology Ventures (ATV).',
#  'Founders Mostafa El Sayed and Suryansh Chandra previously worked as lead designers at Zaha Hadid Architecture, and their first product should be a welcome one in their former profession.',
#  'The low-cost, plug and play, table-top robotic arm called Eva is ideally suited for design studios, but has been developed to also work in SMEs from a myriad of other industries.',
#  '4.',
#  'Best robotics startups in the UK: Consequential Robotics\n\n\n\n\n\n\n\n\n© Consequential Robotics\n\n\n\nUniversity of Sheffield spin-out Consequential Robotics was established to develop companion and assistive robotic systems to\xa0enhance quality of life as people age.',
#  'The first product developed by the startup is a mechanical pet with dog-like features called MiRO that is said to be "the first robot that thinks like an animal".',
#  'MiRo is controlled by\xa0technology modelled on the biological brain, and a\xa0limited number are currently available to professional researchers for £1,900 plus tax and\xa0shipping.',
#  "Iconic British designer Sebastian Conran teamed up with\xa0the university's Professor Tony Prescott and Dr Ben Mitchinson\xa0to found the company in 2016.",
#  "The research was supported by Innovate UK and it's received funding as part of an EU project.",
#  '5.',
#  'Best robotics startups in the UK: Ai Build\n\n\n\n\n\n\n\n\n© Ai Build\n\n\n\nAi Build\xa0wants to develop robotic technologies to support 3D printing in the built environment.',
#  'The London startup was born in November 2015 and attracted £75,000 of seed funding from Seedcamp the next year.',
#  'Founder Daghan Cam envisions a future of construction in which industrial robotics and machine learning automate fabrication processes and help make large-scale 3D printing affordable.',
#  'Last October the company unveiled the Daedalus Pavilion to showcase the technology’s potential.',
#  'The 5m high and 4.5m wide structure was\xa0built using a customised KUKA robotic arm and a 3D printing gun.',
#  '6.',
#  'Best robotics startups in the UK: Reach Robotics\n\n\n\n\n\n\n\n\n© Reach Robotics\n\n\n\nBristol-based Reach Robotics is developing monster robots controlled by mobile devices to use with video games.',
#  'The company has created more than thirty prototypes since it was launched in 2014, but the first design to be released commercially is MekaMon.',
#  'The customisable machines are designed to let players engage in combat through augmented reality gaming and are currently available from $275 (£224).',
#  'Reach Robotics has secured a disclosed total of $250,000 (£200,575) in seed funding so far from seven different investors.',
#  '7.',
#  'Best robotics startups in the UK: OpenBionics\n\n\n\n\n\n\n\n\n© OpenBionics\n\n\n\nOpen Bionics designs\xa03D-printed bionic hands for amputees using medical grade materials.',
#  'The open source initiative produces devices that are easily reproduced using off-the-shelf materials and teamed up with Disney in 2015 to create a superhero-themed range of prosthetics for children.',
#  'The company has received a total of $120,000 (£96,270) equity funding and $20,000 (£16,045) seed funding.',
#  'In February it added\xa0$1 million (£802,100) in prize money after beating more than 1,000 other entrants to the International UAE Robotics for Good Award.',
#  'The winnings will be used to\xa0push the product through\xa0the final stages of medical testing before it can be made available to everyone who needs it.',
#  '8.',
#  'Best robotics startups in the UK: Animal Dynamics\n\n\n\n\n\n\n\n\n© Animal Dynamics\n\n\n\nOxfordshire startup Animal Dynamics\xa0emerged as a spinout company from the Department of Zoology at Oxford University that builds bio-inspired vehicles using\xa0deep science to understand naturally-evolved designs.',
#  'The team are working to develop a portfolio of products based on research into flight, swimming and walking in the natural world.',
#  'The company was co-founded by biomechanics professor Dr Adrian Thomas and entrepreneur Alex Caccia in 2015, and\xa0has attracted seed funding from angel investors Oxford Technology and the University of Oxford Isis Fund (UOIF) to build and test its first products and an undisclosed amount of Series A funding.',
#  '9.',
#  "Best robotics startups in the UK: Moley Robotics\n\n\n\n\n\n\n\n\n© Moley Robotics\n\n\n\nThe creators of\xa0Moley Robotics claim to have designed the\xa0world's first robotic kitchen.",
#  'The automated chef is operated by a smartphone and combines the standard kitchen equipment of\xa0oven, hob and sink with the unusual addition of two dexterous robotic arms that\xa0take care of the cooking.',
#  'The company has raised a total of $1.17 million (£939,000)\xa0in equity crowdfunding since it was founded in 2014.',
#  'A\xa0prototype of the device won the\xa0"Best of the Best" award at the Consumer Electronics Show (CES) in Shanghai the next year, and a consumer version\xa0is set to launch sometime in 2017, supported by an iTunes-style library of different recipes.',
#  '10.',
#  'Best robotics startups in the UK: Primo Toys\n\n\n\n\n\n\n\n\n© Primo Toys\n\n\n\nPrimo Toys are designed to help children learn, play and create with technology.',
#  'Their first release is a wooden robot called Cubetto that helps teach young children how to code through tactile learning.',
#  'Cubetto is placed atop a map on a floor mat and the child puts coloured blocks on\xa0a\xa0board that tell the smiling robot\xa0where to go.',
#  'The company was founded in 2013 by Matteo Loglio\xa0and\xa0Filippo Yacob to help kids become creators of technology rather than just consumers.',
#  "They've attracted a total of $1.18 million (£950,000)\xa0in funding so far, from investors including Randi Zuckerberg, the sister of Facebook founder Mark.",
#  'Cubetto is currently available to buy for $225 (£180).',
#  '11.',
#  'Best robotics startups in the UK: Emotech\n\n\n\n\n\n\n\n\n© Emotech\n\n\n\nLondon-based startup Emotech\xa0has designed what it bills as "the first personal robot with individual personality."',
#  'The deep-learning capabilities of the voice-controlled device known as "Olly" let it adapt to the personality of its user over time through daily interactions.',
#  'The technology won the creators four different\xa0CES Innovation Awards\xa0in 2017.',
#  'The robotics startup was founded in August 2014 to explore ways of improving the relationships between people and technology and has already secured\xa0$10 million (£8 million) of Series A funding from Alliance Capital and Lightning Capital, plus an undisclosed amount of angel funding.',
#  '12.',
#  'Best robotics startups in the UK: Q-Bot\n\n\n\n\n\n\n\n\n© Q-Bot\n\n\n\nSerial entrepreneur Tom Lipinski developed Q-Bot after he uncovered a problem with laying floor insulation in older homes while working on a previous project aimed at\xa0reducing domestic energy use.',
#  'Q-Bot is his solution.',
#  'The tiny four-wheeled robot is\xa0inserted through an air vent armed with a 3D scanner and insulating foam to survey the underside of floorboards and apply insulation as required.',
#  'Q-Bot was founded in 2012 and\xa0won best startup at the Invention and Entrepreneurship in Robotics and Automation Awards in Seattle in 2015.',
#  'The system has been trialled with clients including Camden Council and CityWest Homes, and the company claims it can save\xa0between £200 and £300 a year in energy bills.',
#  'A total of £2 million has been invested in Q-Bot from the EU Horizon 2020 Programme and\xa0two rounds of seed funding.',
#  '13.',
#  'Best robotics startups in the UK: Starship Technologies\n\n\n\n\n\n\n\n\n© Starship Technologies\n\n\n\nStarship Technologies develops small self-driving robots\xa0designed to deliver goods locally within 30 minutes.',
#  'The electric six-wheeled personal couriers drive on pavements at a pedestrian speed of four miles per hour to the location of the customer who then unlock the delivery using their personal code.',
#  'The startup is headquartered in London but its engineering operations are based in Estonia.',
#  'Skype co-founders\xa0Janus Friis and Ahti Heinla created the company in 2015 and have gained $17.2 million (£13.8 million) of funding from eight investors\xa0including\xa0HOF Capital\xa0and\xa0Playfair Capital.',
#  '14.',
#  'Best robotics startups in the UK: Robotical\n\n\n\n\n\n\n\n\n© Robotical Ltd\n\n\n\nDr Alexander Enoch developed his idea for\xa0Robotical while\xa0working with\xa0bulky\xa0machines\xa0during\xa0his\xa0PhD in Robotics studies at the University of Edinburgh.',
#  'The compact\xa0bipedal robot called Marty harnesses the power of play to teach computer skills to children\xa0by letting them\xa0reprogramme the device and customise its\xa03D-printed parts.',
#  "The company has received funding from the the Royal Academy of Engineering's Enterprise Hub and more than £86,000 on a crowdfunding platform.",
#  'Marty is currently available at a special pre-order price of £99 plus shipping.',
#  "P\n\n\n\n\nShare \n\nTwitter\nFacebook\nLinkedIn\nGoogle Plus\n\n\nRecommended for you\nTechworld Daily Bytes - 02 December 2015 - [Tips for funding any business]\nUK Technology Strategy Board send British robotics firms over the pond\n\n\nComments\n\n\n\n\nrequire(['jquery', 'underscore', 'scrollListener'], function($, _, scrollListener){\nvar $el = $('#comments-container-CC24AF6B-C05D-4BF4-99F059755B702665'),\n$pixel = $el.find('.livefyre-comments__loadinview');\nvar loadComments = _.once(function(){\n$el.removeClass('livefyre-comments--headeronly')\n.find('> .crossHead')\n.removeClass('crossHead--btn')\n.text('Comments');\n$el.find('.lfInnerComments')\n.removeClass('lfInnerComments--notloading');\nvar networkConfig = {\nnetwork: 'idg.fyre.co'\n};\nvar convConfig = {\nsiteId: '383032',\narticleId: '115-3654908',\nel: 'comments-CC24AF6B-C05D-4BF4-99F059755B702665',\ncollectionMeta: 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..zteXENfSPC2HbgGBO2-z28xnDCTIAG1EUnsTDumlTEM',\nchecksum: '6ad1b6982428a401a7035a2d644c8ad5',\nauthPageReload: true\n};\nrequire(['livefyreComments'], function(lfComments){\nnew lfComments({\nel: $('#comments-container-CC24AF6B-C05D-4BF4-99F059755B702665').get(0),\nconvConfig: convConfig,\nnetworkConfig: networkConfig\n});\n});\nscrollListener.offElementInView(loadComments, $pixel);\n});\n$el.one('click', '*', null, loadComments);\nscrollListener.onElementInView(loadComments, $pixel);\n});\n\n\n\nLatest UK\n\nul.listing li.sponsored{background-color:#ebebeb;}ul.listing li.sponsored .tags li:first-child{background-color:#ebebeb;border:1px solid #45BCDD;}\n\n\n\n\n\n\n\n\n\n\n\n\nHow to keep innovating while growing at scale\nThe head of R&D and work futurist at Atlassian reveals how the company balances innovation with growth\n\n\n\n\n\n\n\n\n\n\n\n\nWannaCry explained: What is WannaCry ransomware and how does it work?",
#  "The NHS saw one of the biggest ransomware attacks in recent history last week with 47 NHS Trusts affected\n\n\n\n\n\n\n\nLatest UK\n\nul.listing li.sponsored{background-color:#ebebeb;}ul.listing li.sponsored .tags li:first-child{background-color:#ebebeb;border:1px solid #45BCDD;}\n\n\n\n\n\n\n\n\nrequire(['jquery', 'insertAd', 'jstorage'], function($, insertAd) {\nvar showSharethrough = !",
#  '!true;\nvar sidebarElId = \'inArticleRelated\';\nwindow.$geoLocationDef.done(function(){\nvar countryCode = $.jStorage.get(\'GEO_LOC_DATA\').countryCode;\nif(countryCode === \'GB\' && showSharethrough){\n$(\'#geo-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-uk\').append(\'<li class="media"><div id="F5CCCA69-1495-4109-8DFCD145AE2A88EEuk1"></li>\');\ninsertAd($(\'#F5CCCA69-1495-4109-8DFCD145AE2A88EEuk1\'),\'sharethroughLatest\');\n}else{\n$(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk\').append(\'<li class="media"><div id="F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk1"></li>\');\n$(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk\').append(\'<li class="media"><div id="F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk2"></li>\');\n$(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk\').append(\'<li class="media"><div id="F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk3"></li>\');\ninsertAd($(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk .media #F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk1\'),\'sharethroughLatest\');\ninsertAd($(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk .media #F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk2\'),\'sharethroughLatest\');\ninsertAd($(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE .module .listing.gridView.geo-non-uk .media #F5CCCA69-1495-4109-8DFCD145AE2A88EEnonuk3\'),\'sharethroughLatest\');\n$(\'#geo-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE\').hide();\n$(\'#geo-non-ukF5CCCA69-1495-4109-8DFCD145AE2A88EE\').show();\n}\n});\n});\n\n\n\n\nrequire([\'jstorage\'], function() {\nwindow.$geoLocationDef.done(function(){\nvar countryCode = $.jStorage.get(\'GEO_LOC_DATA\').countryCode;\nvar divId = \'7A7AAB33-3B90-4EDB-80B6643789FC13F4\';\nif(false && countryCode==="GB") return;//if commercial and uk - dont show\nvar w = (countryCode==="GB") ?',
#  '40963 : 40960;\nvar referer="";try{if(referer=document.referrer,"undefined"==typeof referer)throw"undefined"}catch(exception){referer=document.location.href,(""==referer||"undefined"==typeof referer)&&(referer=document.URL)}referer=referer.substr(0,700);\nvar rcel = document.createElement("script");\nrcel.id = \'rc_\' + Math.floor(Math.random() * 1000);\nrcel.type = \'text/javascript\';\nrcel.src = "https://trends.revcontent.com/serve.js.php?w="+w+"&t="+rcel.id+"&c="+(new Date()).getTime()+"&width="+(window.outerWidth || document.documentElement.clientWidth)+"&referer="+referer;\nrcel.async = true;\nvar rcds = document.getElementById(divId); rcds.appendChild(rcel);\n});\n});\n\n\nrequire([\'modules/slideshow\'], function(Slideshow){\nnew Slideshow(true, false);\n});\nrequire([\'timeBasedReload\'], function(timeBasedReload){\nnew timeBasedReload(false,false,[],-1,3654908);\n});\n\n\n\n\n\n\n\nvar id = \'fixedSidebarMpu-pos1\';\nvar type = \'fixedSidebarMpu\';\nif(adConfig.debug)console.log(\'ad.cfm id = \',id,\' type = \',type);\nif(type === \'mpu\' && Device.isMobile && adConfig.mpuCount < 2){\nadConfig.mpuCount += 1;\nif(adConfig.debug)console.log(\'adConfig.mpuCount\',adConfig.mpuCount,\'adType\',\'fixedSidebarMpu\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'fixedSidebarMpu-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}else if(type === \'mpu\' && Device.isMobile && adConfig.mpuCount >= 2){\nif(adConfig.debug)console.log(\'nothing\');\n}else{\nif(adConfig.debug)console.log(\'adConfig.mpuCountX\',adConfig.mpuCount,\'adType\',\'fixedSidebarMpu\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'fixedSidebarMpu-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}\n\n\n\n\n\nMost Popular\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHow to keep innovating while growing at scale\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWannaCry explained: What is WannaCry ransomware and how does it work?',
#  "require(['jquery', 'insertAd', 'jstorage'], function($, insertAd) {\nvar showSharethrough = !",
#  '!true;\nvar sidebarElId = \'sideMod_399D3308-BF14-4FAE-A5E43A0DD882A970\';\nwindow.$geoLocationDef.done(function(){\nvar countryCode = $.jStorage.get(\'GEO_LOC_DATA\').countryCode;\nif (showSharethrough) {\nif (countryCode === \'GB\') {\n$(\'#\' + sidebarElId + \' ul.geo-uk\').prepend(\'<li class="media"><div id="BE2219CC-586F-4416-A586D161814A7F13"></li>\');\ninsertAd($(\'#BE2219CC-586F-4416-A586D161814A7F13\'), \'sharethroughRHC\');\n}else {\n$(\'#\' + sidebarElId + \' h3\').text(\'Promoted Content\');\n$(\'#\' + sidebarElId + \' ul.geo-non-uk\').show();\n$(\'#\' + sidebarElId + \' ul.geo-uk\').hide();\n$(\'#\' + sidebarElId + \' ul.geo-non-uk li div\').each(function(index){\ninsertAd($(\'#\' + $(this).attr(\'id\')), \'sharethroughRHC\');\n});\n}\n}\n});\n});\n\n\n\n\xa0\n\n\n\n\n\n\n\nvar id = \'sixFortyXFourEighty-pos1\';\nvar type = \'sixFortyXFourEighty\';\nif(adConfig.debug)console.log(\'ad.cfm id = \',id,\' type = \',type);\nif(type === \'mpu\' && Device.isMobile && adConfig.mpuCount < 2){\nadConfig.mpuCount += 1;\nif(adConfig.debug)console.log(\'adConfig.mpuCount\',adConfig.mpuCount,\'adType\',\'sixFortyXFourEighty\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'sixFortyXFourEighty-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}else if(type === \'mpu\' && Device.isMobile && adConfig.mpuCount >= 2){\nif(adConfig.debug)console.log(\'nothing\');\n}else{\nif(adConfig.debug)console.log(\'adConfig.mpuCountX\',adConfig.mpuCount,\'adType\',\'sixFortyXFourEighty\',\'Device.isMobile\',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = \'sixFortyXFourEighty-pos1\';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log(\'rendering ad id = \' + id);\ngoogletag.display(id);\n}\n});\n}\n\n\n\n\n\n\nrequire([\'jquery\', \'jstorage\'], function($){\nif (!$.jStorage.get(\'cookieShown\')) {\nrequire(["cookieBar"], function(a){\n$(document).ready(function(){\na.init();\n});\n});\n}\n$.jStorage.set(\'cookieShown\', true)\n});\n\n\n\n\nConnect\n\ntw\nin\nfb\ngplus\njobbio\n\nNewsletter\n\n(function(){\nvar toExec = function($, ouibounce){\nif(typeof window.ouibounce === \'undefined\' && typeof arguments[1] !== \'undefined\'){\nwindow.ouibounce = ouibounce;\n}\nvar $btn = $(\'#newsletter-signup-btn--06FB48A3-1D70-466B-BB5C37DB4F4CB2E9 .newsletter-signup-btn__btn:not([data-has-trigger])\');\n$btn.attr(\'data-has-trigger\', \'true\');\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - attaching event listener to sign up button\', arguments);\n$btn.on(\'click\', null, null, function(e){\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - opening form\', arguments);\ne.preventDefault();\n$btn.addClass(\'newsletter-signup-btn__btn--loading\');\nwindow.idguk.blitzen.openNewsletterSignUpForm();\nvar checkCount = 0,\ncheckInterval;\ncheckInterval = setInterval(function(){\ncheckCount++;\nvar $iframe = $(\'#\' + setting(\'BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID\')),\nclearIt = false;\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - loading check\', $iframe);\nif($iframe.length){\nif($iframe.attr(\'data-loaded\') == 1){\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - loading check - clearing\', $iframe, checkCount);\nclearIt = true;\n}else{\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - loading check - not loaded\', $iframe, checkCount);\n}\n}else{\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - loading check - iframe not found\', $iframe, checkCount);\n}\nif(clearIt || checkCount > 10){\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up button - loading check - clearing interval\', $iframe, checkCount);\n$btn.removeClass(\'newsletter-signup-btn__btn--loading\');\nclearInterval(checkInterval);\n}\n}, 1000);\n});\n};\nif((typeof require !== \'undefined\')) ...
#  '(function(){\nvar toExec = function($, ouibounce){\nif(typeof window.ouibounce === \'undefined\' && typeof arguments[1] !== \'undefined\'){\nwindow.ouibounce = ouibounce;\n}\nvar $container = $(\'#newsletter-signup--80468B52-ABC8-4BE2-B13C0C008F74E984\');\nvar $form = $container.find(\'form[name="newsletter-signup-form"]\');\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up form - attaching event listener to sign up form\', arguments);\n$form.on(\'submit\', null, null, function(e){\nif(setting(\'BOOMTRAIN_DEBUG\'))console.log(\'blitzen sign up form - opening form\', arguments);\ne.preventDefault();\nvar email = $form.find(\'input[name="email"]\').val();\n//TODO something ??',
#  "/*\n_bt.trackAccountSignup(email, {\n'source': 'site_newsletter_form'\n});\n*/\nwindow.idguk.blitzen.openNewsletterSignUpForm('email=' + email);\n});\n};\nif((typeof require !== 'undefined')){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up form - found require');\nrequire(['jquery', 'blitzenForm'], toExec);\n}else if(typeof idguk.require !== 'undefined'){\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up form - found idguk.require');\nidguk.require (['jquery', 'blitzenForm'], toExec);\n}else{\nif(setting('BOOMTRAIN_DEBUG'))console.log('blitzen sign up form - exec now');\ntoExec($);\n}\n})();\n\n\n\n\nExplore\n\nNews\nBlogs\nFeatures\nAnalysis\nTutorials\nReviews\nCareer\nResources\nGalleries\nDownloads\nWhite Papers\nTechworld Authors\n\n\n\nAbout\n\nAbout Us\nContact Us\nAdvertise\nT's & C's\n\nPrivacy Policy\nRSS\nSite Map\nCookies\n\n\n\n\n© Copyright 2017 IDG UK.",
#  'All Rights Reserved.',
#  'if (typeof skimlinks !== \'undefined\') {\nvar skimlinks_pub_id = \'91802X1545673\';\nvar skimlinks_exclude = Array(\'ad.uk.doubleclick.net\', \'adserver.adtech.de\');\nvar skimlinks_exrel = \'noskim\';\nskimlinks();\n};\n\n\nrequire([\'jstorage\'], function() {\nwindow.$geoLocationDef.done(function(){\nvar countryCode = $.jStorage.get(\'GEO_LOC_DATA\').countryCode;\nif (countryCode!="GB") {\nvar protocol = (\'https:\' == document.location.protocol ?',
#  '\'https://\' : \'http://\');\nvar s = document.createElement(\'script\'); s.src = protocol + "s.skimresources.com/js/91802X1546659.skimlinks.js";\nvar x = document.getElementsByTagName(\'script\')[0]; x.parentNode.insertBefore(s, x);\n};\n});\n});\n\n \n\nvar _comscore = _comscore || [];\n_comscore.push({ c1: "2", c2: "6035308" });\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;\ns.src = (document.location.protocol == "https:" ?',
#  '"https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";\nel.parentNode.insertBefore(s, el);\n})();\n\n\n\n\n \n\n//script to log clicks to ga automatically, requires positioning of data-ga=""attributes on selected areas\n$(\'[data-ga] a\').on(\'click\',function(){\nvar el = $(this).closest(\'[data-ga]\');\nvar linkText = $(this).attr(\'title\') ?',
#  '$(this).attr(\'title\') : $(this).text();\nvar debug = false;\nfunction f(s){\nreturn s.replace(/[^a-zA-Z0-9_\\- ]/gim,\'\');\n}\nvar path = [];//the google analytics "path", look for only 2 levels to avoid clutter\nif(el.size()===1){\npath.push(el.data(\'ga\'));\nel = el.parent().closest(\'[data-ga]\');\nif(el.size()===1)path.push(el.data(\'ga\'));\n}\nif(path.length > 0){\nif(debug)console.log(\'GAevent\',{\'event\':\'GAevent\', \'eventCategory\':\'Click\', \'eventAction\': path.reverse().join(\'/\'), \'eventLabel\': f(linkText)});\ndataLayer.push({\'event\':\'GAevent\', \'eventCategory\':\'Click\', \'eventAction\': path.reverse().join(\'/\'), \'eventLabel\': f(linkText)});\n}\nif(debug)return false;\n});\n\n\n/* <!',
#  '[CDATA[ */\nif (typeof(pagearSmallImg) != "undefined") {\nacoeSrc = "/views/structure/pageear/AC_OETags.js?',
#  '";\npageEarSrc = "/views/structure/pageear/pageear.js?',
#  '";\nacoeScript = \'<scr\' + \'ipt type="text/javascript" src="\'+acoeSrc+\'"></scr\' + \'ipt>\';\npageEarScript = \'<scr\' + \'ipt type="text/javascript" src="\'+pageEarSrc+\'"></scr\' + \'ipt>\';\ndocument.write(acoeScript);\ndocument.write(pageEarScript);\n}\n/* ]]> */\n\n \n\n\n\nvar blueKaiDebug = false;\n//blueKaiDebug = true;\nif(blueKaiDebug)console.log(\'bluekai active\');\nbk_addPageCtx("cmscatnms", "[personal-tech,startups]");\nif(blueKaiDebug)console.log(\'bluekai cmscatnms=[personal-tech,startups]\');\nbk_doJSTag(18918, 4);\n<!-- End BlueKai Tag -->\n\n\nvar _sf_async_config = { uid: 51485, domain: \'techworld.com\', useCanonical: true };\n(function() {\nfunction loadChartbeat() {\nwindow._sf_endpt = (new Date()).getTime();\nvar e = document.createElement(\'script\');\ne.setAttribute(\'language\', \'javascript\');\ne.setAttribute(\'type\', \'text/javascript\');\ne.setAttribute(\'src\',\'//static.chartbeat.com/js/chartbeat.js\');\ndocument.body.appendChild(e);\n};\nvar oldonload = window.onload;\nwindow.onload = (typeof window.onload != \'function\') ?',
#  "loadChartbeat : function() { oldonload(); loadChartbeat(); };\n})();\n\n\n(function(d, s, host, ipid) {\nvar e = d.createElement(s);\ne.type = 'application/javascript';\ne.async = !0;\ne.src = '//' + host + '/intellitxt/front.asp?ipid=' + ipid;\nd.getElementsByTagName(s)[0].parentNode.appendChild(e);\n})(document, 'script', 'k.intellitxt.com', 90692);\n\n\nrequire(['jquery'], function($){\n$.ajax({\nurl: '/',\ntype: 'POST',\ncache: false,\ndata: {\n'event': 'Main.trackUserActions',\n't': '44CC8BC9A698842B2A6CB4D68D9E91DD37D7BBCB6F7B9D8B31415CC953B4986F7415DDEDC21E36F306FA23E9C9140FD9CB160DD7570B3B8387A2CF74D62E2E8E'\n}\n}).done(function( ) {\n//alert('success');\n});\n});\n\n \n\n\n(function(){\nvar Queue = function(){\nthis.push = function(e){\nif(typeof _bt === 'undefined' || this.length > 0){\nArray.prototype.push.call(this, e);\n}else{\ne();\n}\n};\n};\nQueue.prototype = [];\nwindow._btQueue = new Queue();\nvar btCheckInterval = setInterval(function(){\nif(typeof _bt === 'undefined'){\nreturn;\n}\nvar func;\nwhile(typeof (func = _btQueue.shift()) !== 'undefined'){\nfunc();\n}\nclearInterval(btCheckInterval);\n}, 1000);\n/*\n_btQueue.push(function(){\n});\n*/\nvar toExec = function($){\n_btQueue.push(function(){\n$('body').on('click', '.logout_link', null, function(){\n_bt.clear();\n});\n});\n};\nif(typeof require !== 'undefined'){\nrequire(['jquery'], toExec);\n}else{\ntoExec($);\n}\n})();\n\n\n(function(){\n'use strict';\nwindow.idguk = window.idguk || {};\nwindow.idguk.blitzen = {\nopenNewsletterSignUpForm: function(qs){\nqs = qs || '';\nif(setting('BOOMTRAIN_DEBUG'))console.log('openNewsletterSignUpForm called', arguments);\nif(qs.length > 0 && (!new RegExp('^\\\\?",
#  "').test(qs))){\nqs = '?'",
#  "+ qs;\n}\nvar $existingForm = $('iframe#' + setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID'));\nvar $existingWrapper = $('div#' + setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID') + '_wrapper');\nif($existingForm.length > 0){\n$existingForm.remove();\n$existingWrapper.remove();\n}\nvar onLoad = function(){\nif(setting('BOOMTRAIN_DEBUG'))console.log('onload called for blitzen iframe', arguments, this);\nvar resizeIt = function(){\nresizeCrossDomainIframe(setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID'), setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_URL') + qs);\n};\nif(typeof require !== 'undefined'){\nrequire(['blitzenForm'], function(){\nresizeIt();\n});\n}else if(typeof idguk.require !== 'undefined'){\nidguk.require(['blitzenForm'], function(){\nresizeIt();\n});\n}else{\nresizeIt();\n}\n/*\ndelay as iframe may not be on the page yet (even though onload is called!!??)",
#  "and loaded doesnt mean it is visible yet anyway\n*/\nsetTimeout(function(){\n$('iframe#' + setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID')).attr('data-loaded', '1');\n}, 5000)\nif(setting('BOOMTRAIN_DEBUG'))console.log('onload finished for blitzen iframe', arguments, this);\n};\nvar $iframe = $('<iframe/>', {\n'id': setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID'),\n'src': setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_URL') + qs,\n'class': 'blitzen-form-wrapper__form',\n'onload': onLoad,\n'data-loaded': '0'\n});\nvar $wrapper = $('<div/>', {\n'id': setting('BLITZEN_NEWSLETTER_REGISTRATION_FORM_ID') + '_wrapper',\n'class': 'blitzen-form-wrapper'\n})\n$wrapper.appendTo('body');\n$iframe.attr('resize', 'true');\n$iframe.attr('width', '0px');\n$iframe.attr('height', '0px');\n$iframe.appendTo($wrapper);\n}\n};\n})();\n\n\n\nvar id = 'avid-pos1';\nvar type = 'avid';\nif(adConfig.debug)console.log('ad.cfm id = ',id,' type = ',type);\nif(type === 'mpu' && Device.isMobile && adConfig.mpuCount < 2){\nadConfig.mpuCount += 1;\nif(adConfig.debug)console.log('adConfig.mpuCount',adConfig.mpuCount,'adType','avid','Device.isMobile',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = 'avid-pos1';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log('rendering ad id = ' + id);\ngoogletag.display(id);\n}\n});\n}else if(type === 'mpu' && Device.isMobile && adConfig.mpuCount >= 2){\nif(adConfig.debug)console.log('nothing');\n}else{\nif(adConfig.debug)console.log('adConfig.mpuCountX',adConfig.mpuCount,'adType','avid','Device.isMobile',Device.isMobile);\ngoogletag.cmd.push(function(){\nvar id = 'avid-pos1';\nif (id in adConfig.adsToRefresh) {\nif(adConfig.debug)console.log('rendering ad id = ' + id);\ngoogletag.display(id);\n}\n});\n}\n\n\n \n \n \n\n/* <!",
#  "[CDATA[ */(function(d,s,a,i,j,r,l,m,t){try{l=d.getElementsByTagName('a');t=d.createElement('textarea');for(i=0;l.length-i;i++){try{a=l[i].href;s=a.indexOf('/cdn-cgi/l/email-protection');m=a.length;if(a&&s>-1&&m>28){j=28+s;s='';if(j<m){r='0x'+a.substr(j,2)|0;for(j+=2;j<m&&a.charAt(j)!='X';j+=2)s+='%'+('0'+('0x'+a.substr(j,2)^r).toString(16)).slice(-2);j++;s=decodeURIComponent(s)+a.substr(j,m-j)}t.innerHTML=s.replace(/</g,'&lt;').replace(/\\>/g,'&gt;');l[i].href='mailto:'+t.value}}catch(e){}}}catch(e){}})(document);/* ]]> */"]
