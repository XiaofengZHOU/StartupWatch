# %%
import nltk
import json

import json
f=open('data/data.json','r')
articles = json.load(f)    
f.close()

    
article = articles["TechWorld"][3]
content = article["content"]

# %%
sentences =  nltk.sent_tokenize(content)
for sent in sentences:
    tokens = nltk.word_tokenize(sent)
    pos = nltk.pos_tag(tokens)

    for item in pos:
        if item[1]=='NNP':
            print(item)
# Out:
# ('Cambridge', 'NNP')
# ('Darktrace', 'NNP')
# ('Cyber', 'NNP')
# ('Darktrace', 'NNP')
# ('Darktrace', 'NNP')
# ('AI', 'NNP')
# ('Darktrace', 'NNP')
# ('CEO', 'NNP')
# ('Nicole', 'NNP')
# ('Eagan', 'NNP')
# ('Techworld', 'NNP')
# ('Darktrace', 'NNP')
# ('PS51', 'NNP')
# ('KKR', 'NNP')
# ('July', 'NNP')
# ('BenevolentAI', 'NNP')
# ('UK', 'NNP')
# ('AI', 'NNP')
# ('NVIDIA', 'NNP')
# ('BenevolentAI', 'NNP')
# ('BenevolentAI', 'NNP')
# ('AI', 'NNP')
# ('UK', 'NNP')
# ('A', 'NNP')
# ('PS72', 'NNP')
# ('London', 'NNP')
# ('Onfido', 'NNP')
# ('Darktrace', 'NNP')
# ('Oxford', 'NNP')
# ('Onfido', 'NNP')
# ('Onfido', 'NNP')
# ('B', 'NNP')
# ('PS19', 'NNP')
# ('April', 'NNP')
# ('Idinvest', 'NNP')
# ('Digital', 'NNP')
# ('Genius', 'NNP')
# ('Digital', 'NNP')
# ('Genius', 'NNP')
# ('Digital', 'NNP')
# ('Genius', 'NNP')
# ('Zendesk', 'NNP')
# ('Salesforce', 'NNP')
# ('Microsoft', 'NNP')
# ('PS8', 'NNP')
# ('Salesforce', 'NNP')
# ('Ventures', 'NNP')
# ('Bloomberg', 'NNP')
# ('Beta', 'NNP')
# ('Lumia', 'NNP')
# ('Capital', 'NNP')
# ('US', 'NNP')
# ('San', 'NNP')
# ('Francisco', 'NNP')
# ('KLM', 'NNP')
# ('Unilever', 'NNP')
# ("L'Oreal", 'NNP')
# ('Echobox', 'NNP')
# ('AI', 'NNP')
# ('Founder', 'NNP')
# ('Antoine', 'NNP')
# ('Amann', 'NNP')
# ('Cambridge', 'NNP')
# ('Financial', 'NNP')
# ('Echobox', 'NNP')
# ('Entrepreneur', 'NNP')
# ('First', 'NNP')
# ('Amann', 'NNP')
# ('Echobox', 'NNP')
# ('AI', 'NNP')
# ('Echobox', 'NNP')
# ('Facebook', 'NNP')
# ('Twitter', 'NNP')
# ('A/B', 'NNP')
# ('RIP', 'NNP')
# ('Vice', 'NNP')
# ('Telegraph', 'NNP')
# ('UK', 'NNP')
# ('Echobox', 'NNP')
# ('PS2.7', 'NNP')
# ('A', 'NNP')
# ('July', 'NNP')
# ('Mangrove', 'NNP')
# ('Capital', 'NNP')
# ('Partners', 'NNP')
# ('Ravelin', 'NNP')
# ('Hailo', 'NNP')
# ('COO', 'NNP')
# ('Nick', 'NNP')
# ('Lally', 'NNP')
# ('Techworld', 'NNP')
# ('Stripe', 'NNP')
# ('APIs', 'NNP')
# ('Ravelin', 'NNP')
# ('Deliveroo', 'NNP')
# ('EasyTaxi', 'NNP')
# ('PS3', 'NNP')
# ('October', 'NNP')
# ('Playfair', 'NNP')
# ('Capital', 'NNP')
# ('Amadeus', 'NNP')
# ('Capital', 'NNP')
# ('Passion', 'NNP')
# ('Capital', 'NNP')
# ('Stepsize', 'NNP')
# ('AI', 'NNP')
# ('Stepsize', 'NNP')
# ('Layer', 'NNP')
# ('Slack', 'NNP')
# ('UCL', 'NNP')
# ('Matthieu', 'NNP')
# ('Louis', 'NNP')
# ('Nick', 'NNP')
# ('Omeyer', 'NNP')
# ('Stepsize', 'NNP')
# ('Virgin', 'NNP')
# ('Media', 'NNP')
# ('Accelerator', 'NNP')
# ('Programme', 'NNP')
# ('Phrasee', 'NNP')
# ('Phrasee', 'NNP')
# ('AI', 'NNP')
# ('Phrasee', 'NNP')
# ('PS1', 'NNP')
# ('Grip', 'NNP')
# ('London', 'NNP')
# ('AI', 'NNP')
# ('Networkr', 'NNP')
# ('April', 'NNP')
# ('CEO', 'NNP')
# ('Tim', 'NNP')
# ('Groot', 'NNP')
# ('Techworld', 'NNP')
# ('Grip', 'NNP')
# ('LinkedIn', 'NNP')
# ('Twitter', 'NNP')
# ('Think', 'NNP')
# ('Grip', 'NNP')
# ('Groot', 'NNP')
# ('Techworld', 'NNP')
# ('Grip', 'NNP')
# ('Cannes', 'NNP')
# ('Lions', 'NNP')
# ('AI', 'NNP')
# ('Groot', 'NNP')
# ('Copenhagen', 'NNP')
# ('Grip', 'NNP')
# ('Intros.at', 'NNP')
# ('Groot', 'NNP')
# ('Reed', 'NNP')
# ('Exhibitions', 'NNP')
# ('Cannes', 'NNP')
# ('Lions', 'NNP')
# ('Seldon', 'NNP')
# ('AI', 'NNP')
# ('Seldon', 'NNP')
# ('API', 'NNP')
# ('Seldon', 'NNP')
# ('Seldon.io', 'NNP')
# ('YouGov', 'NNP')
# ('Lastminute.com', 'NNP')
# ('RatedPeople.com', 'NNP')
# ('Barclays', 'NNP')
# ('London', 'NNP')
# ('Techstars', 'NNP')
# ('London', 'NNP')
# ('Tractable', 'NNP')
# ('AI', 'NNP')
# ('AI', 'NNP')
# ('AI', 'NNP')
# ('Alex', 'NNP')
# ('Dalyac', 'NNP')
# ('Imperial', 'NNP')
# ('College', 'NNP')
# ('London', 'NNP')
# ('Razvan', 'NNP')
# ('Ranca', 'NNP')
# ('Cambridge', 'NNP')
# ('University', 'NNP')
# ('PS1.4', 'NNP')
# ('June', 'NNP')
# ('Zetta', 'NNP')
# ('Venture', 'NNP')
# ('Farfetch', 'NNP')
# ('AI', 'NNP')
# ('AI', 'NNP')
# ('UCL', 'NNP')
# ('Deep', 'NNP')
# ('Mind', 'NNP')
# ('Demis', 'NNP')
# ('Hassabis', 'NNP')
# ('PS65,000', 'NNP')
# ('Seedcamp', 'NNP')
# ('Seedcamp', 'NNP')
# ('London', 'NNP')
# ('Cleo', 'NNP')
# ('Barney', 'NNP')
# ('Hussey-Yeo', 'NNP')
# ('Aleksandra', 'NNP')
# ('Wozniak', 'NNP')
# ('Entrepreneur', 'NNP')
# ('First', 'NNP')
# ('Cleo', 'NNP')
# ('Cleo', 'NNP')
# ('McKinsey', 'NNP')
# ('Goldman', 'NNP')
# ('Sachs', 'NNP')
# ('UK', 'NNP')
# ('Entrepreneur', 'NNP')
# ('First', 'NNP')
# ('AI', 'NNP')
# ('Brolly', 'NNP')
# ('Brolly', 'NNP')
# ('Android', 'NNP')
# ('Entrepreneur', 'NNP')
# ('First', 'NNP')
# ('StatusToday', 'NNP')
# ('StatusToday', 'NNP')
# ('PS1', 'NNP')
# ('February', 'NNP')
# ('UK', 'NNP')
# ('Notion', 'NNP')
# ('Capital', 'NNP')
# ('LocalGlobe', 'NNP')
# ('Force', 'NNP')
# ('Mass', 'NNP')
# ('Capital', 'NNP')
# ('Entrepreneur', 'NNP')
# ('First', 'NNP')
# ('New', 'NNP')
# ('Agolo', 'NNP')
# ('Twitter', 'NNP')
# ('Agolo', 'NNP')
# ('PS2.7', 'NNP')
# ('Microsoft', 'NNP')
# ('Microsoft', 'NNP')
# ('Ventures', 'NNP')
# ('Agolo', 'NNP')
# ('Berkeley', 'NNP')
# ('California', 'NNP')
# ('Bonsai', 'NNP')
# ('Agolo', 'NNP')
# ('PS5.8', 'NNP')
# ('Microsoft', 'NNP')
# ('Ventures', 'NNP')
# ('New', 'NNP')
# ('Enterprise', 'NNP')
# ('Bonsai', 'NNP')
# ('AI', 'NNP')
# ('TensorFlow', 'NNP')
# ('Microsoft', 'NNP')
# ('CNTK', 'NNP')

# %%
nltk.ne_chunk(pos,binary=True)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     724             _canvas_frame.print_to_file(in_path)
#     725             _canvas_frame.destroy_widget(widget)
# --> 726             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     727                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     728                             .format(out_path, in_path).split())
#
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\nltk\__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     600                 binary_names=None, url=None, verbose=True):
#     601     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 602                                  binary_names, url, verbose))
#     603
#     604 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\nltk\__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     594     """
#     595     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 596                      url, verbose):
#     597         yield file
#     598
#
# c:\users\xizhou\appdata\local\programs\python\python36-32\lib\site-packages\nltk\__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     565                         (filename, url))
#     566         div = '='*75
# --> 567         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     568
#     569
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [('Interestingly', 'RB'), (',', ','), Tree('NE', [('Bonsai', 'NNP')]), ("'s", 'POS'), ('AI', 'NNP'), ('framework', 'NN'), ('is', 'VBZ'), ('based', 'VBN'), ('on', 'IN'), Tree('NE', [('TensorFlow', 'NNP')]), (',', ','), ('a', 'DT'), ('Google-owned', 'JJ'), ('machine', 'NN'), ('learning', 'VBG'), ('platform', 'NN'), ('and', 'CC'), ('a', 'DT'), ('competitor', 'NN'), ('to', 'TO'), Tree('NE', [('Microsoft', 'NNP')]), ("'s", 'POS'), Tree('NE', [('CNTK', 'NNP')]), (',', ','), ('an', 'DT'), ('open', 'JJ'), ('source', 'NN'), ('deep-learning', 'JJ'), ('toolkit', 'NN'), ('.', '.')])

# %%
nltk.help.upenn_tagset()
